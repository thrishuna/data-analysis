# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com./v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '84c4ef19-6093-46d4-8b89-d1f2a5f401e7',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:13:27.089Z', 'error_code': 0, 'error_message': None, 'elapsed': 17, 'credit_count': 1, 'notice': None, 'total_count': 8818}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10821, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])

# %%
norm
# Out:
#         id              name  symbol                  slug  num_market_pairs  \
# 0        1           Bitcoin     BTC               bitcoin             10821
# 1     1027          Ethereum     ETH              ethereum              8428
# 2      825       Tether USDt    USDT                tether             74897
# 3     1839               BNB     BNB                   bnb              2070
# 4     5426            Solana     SOL                solana               626
# ..     ...               ...     ...                   ...               ...
# 495   9176  RocketX exchange     RVF  rocket-vault-rocketx                64
# 496  19055   Solidus Ai Tech  AITECH       solidus-ai-tech                45
# 497   3884        Function X      FX            function-x                30
# 498   3661  Stronghold Token     SHX      stronghold-token                30
# 499   3437         ABBC Coin    ABBC             abbc-coin                89
#
#                    date_added  \
# ...

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '84c4ef19-6093-46d4-8b89-d1f2a5f401e7',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:15:41.772Z', 'error_code': 0, 'error_message': None, 'elapsed': 2, 'credit_count': 1, 'notice': None}, 'data': [{'id': 3864, 'name': 'mvphbhbhge', 'symbol': 'midptyju5af', 'slug': '9ym08ujiy6b', 'cmc_rank': 5135, 'num_market_pairs': 2877, 'circulating_supply': 7343, 'total_supply': 1423, 'max_supply': 9452, 'infinite_supply': None, 'last_updated': '2024-02-20T06:15:41.771Z', 'date_added': '2024-02-20T06:15:41.771Z', 'tags': ['pgp0u1p4f0a', 'odm3m60d7b', '4ifdo2dtva9', '9xgyvvbfus', 'q0y5c7cxmad', 'n20hxdfxix', 'ha69ivntgma', '8w6l00a4hoq', '21gcffmaljh', 'l9tsrgcrbx'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.554929386729222, 'volume_24h': 640, 'volume_change_24h': 0.6230996855602844, 'percent_change_1h': 0.2882041661521293, 'percent_change_24h': 0.14189671822524974, 'percent_change_7d': 0.6792647542617172, 'market_cap': 0.7530835017047082, 'market_cap_dominance':
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])

# %%
norm
# Out:
#      id          name       symbol          slug  cmc_rank  num_market_pairs  \
# 0  3864    mvphbhbhge  midptyju5af   9ym08ujiy6b      5135              2877
# 1  5504   23xw6jzojo5  o919z7dwtfq    kpcwjrxkvq      1380              1843
# 2   838   5tgwa6em32k  fk4ptnykzym   4z2df9xcuap      9404              3306
# 3  9156    iumwqh4xbf   7xv8q60hcw    zp9050niet      5537              6141
# 4  9874    5xo38c77py   m9xngtwqix  1m9vbwv4i9zi      7855              5634
# 5   257   p27xv6o3uao  so6g9jkku6e   v2pjs1bayv9      4286              1705
# 6  2082   h0xhrrvu19p  88w6gymvqy7   c7wtujj3mye      8505              6919
# 7  9411   lsq08qtrsal  o1k3d0t2ash   gwcba0faojo      7433              2825
# 8  6317  02esy1fpgbvp  krl2070pqkl   3i5vq41tsx2      3105              3031
# 9  2372   5qb0fc2uofd  6ulhdvwzi5k   9kd9ug35x2j      3503              9252
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# ...

# %% [markdown]
# RANDOM FOX OF API
# Accessing an API which doesnt have an API key

# %%
import requests

# %%
page=requests.get('https://randomfox.ca/floof')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/48.jpg","link":"https:\/\/randomfox.ca\/?i=48"}

# %%
fox=page.json()
image=fox['image']
print(image)
# Out:
# https://randomfox.ca/images/48.jpg

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'http://api.openweathermap.org/data/2.5/forecast?id=524901&appid=260b5bc45c64414e67ff229ff9423e0a'
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '17449c1406285e838c69f5466ee1a15c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1708419600, 'main': {'temp': 261.5, 'feels_like': 254.97, 'temp_min': 261.5, 'temp_max': 265.67, 'pressure': 1030, 'sea_level': 1030, 'grnd_level': 1010, 'humidity': 97, 'temp_kf': -4.17}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 3.59, 'deg': 187, 'gust': 6.67}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2024-02-20 09:00:00'}, {'dt': 1708430400, 'main': {'temp': 265.16, 'feels_like': 259.2, 'temp_min': 265.16, 'temp_max': 268.04, 'pressure': 1029, 'sea_level': 1029, 'grnd_level': 1009, 'humidity': 92, 'temp_kf': -2.88}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 3.83, 'deg': 180, 'gust': 7.22}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2024-02-20 12:00:00'}, {'dt': 1708441200, 'main': {'temp': 265.44, 'fee
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['list'])

# %%
norm
# Out:
#             dt                                            weather  visibility  \
# 0   1708419600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 1   1708430400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 2   1708441200  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 3   1708452000  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 4   1708462800  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 5   1708473600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 6   1708484400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 7   1708495200  [{'id': 804, 'main': 'Clouds', 'description': ...        2310
# 8   1708506000  [{'id': 600, 'main': 'Snow', 'description': 'l...         499
# 9   1708516800  [{'id': 600, 'main': 'Snow', 'description': 'l...         876
# 10  1708527600  [{'id': 600, 'main': 'Snow', 'description': 'l...         451
# ...

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'http://api.weatherapi.com/v1/current.json'
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'cf4e4b3957f24a61aaa71432242002',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'error': {'code': 1002, 'message': 'API key is invalid or not provided.'}}

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['list'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-f3fa015e7af7> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 norm=pd.json_normalize(data['list'])
#
# KeyError: 'list'
