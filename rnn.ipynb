# %%
import numpy as np
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Embedding
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# %%
sentences = ['I love learning','I love python','I hate school','Recurrent Neural Networks are powerful']
# Tokenizing the words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)
total_words = len(tokenizer.word_index) + 1

# %%
#Creating input sequences and their corresponding next words
input_sequences = []
for sentence in sentences:
    tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]
    for i in range(1, len(tokenized_sentence)):
        n_gram_sequence = tokenized_sentence[:i+1]
        input_sequences.append(n_gram_sequence)

# %%
max_sequence_length = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

# %%
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = to_categorical(y, num_classes=total_words)

# %%
model = Sequential()
model.add(Embedding(input_dim=total_words, output_dim=50, input_length=max_sequence_length-1))
model.add(SimpleRNN(100, return_sequences=True))
model.add(SimpleRNN(100))
model.add(Dense(total_words, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 1/1 - 3s - loss: 2.5222 - accuracy: 0.0000e+00 - 3s/epoch - 3s/step
# Epoch 2/50
# 1/1 - 0s - loss: 2.4279 - accuracy: 0.2000 - 15ms/epoch - 15ms/step
# Epoch 3/50
# 1/1 - 0s - loss: 2.3406 - accuracy: 0.5000 - 15ms/epoch - 15ms/step
# Epoch 4/50
# 1/1 - 0s - loss: 2.2562 - accuracy: 0.5000 - 14ms/epoch - 14ms/step
# Epoch 5/50
# 1/1 - 0s - loss: 2.1717 - accuracy: 0.5000 - 16ms/epoch - 16ms/step
# Epoch 6/50
# 1/1 - 0s - loss: 2.0859 - accuracy: 0.5000 - 18ms/epoch - 18ms/step
# Epoch 7/50
# 1/1 - 0s - loss: 1.9988 - accuracy: 0.5000 - 14ms/epoch - 14ms/step
# Epoch 8/50
# 1/1 - 0s - loss: 1.9114 - accuracy: 0.5000 - 17ms/epoch - 17ms/step
# Epoch 9/50
# 1/1 - 0s - loss: 1.8250 - accuracy: 0.4000 - 15ms/epoch - 15ms/step
# Epoch 10/50
# 1/1 - 0s - loss: 1.7407 - accuracy: 0.4000 - 15ms/epoch - 15ms/step
# Epoch 11/50
# 1/1 - 0s - loss: 1.6585 - accuracy: 0.4000 - 13ms/epoch - 13ms/step
# Epoch 12/50
# 1/1 - 0s - loss: 1.5783 - accuracy: 0.4000 - 16ms/epoch - 16ms/step
# ...

# %%
seed_text = input("Enter the starting word: ")
next_words = int(input("Enter how many words to predict: "))
for _ in range(next_words):
    tokenized_seed = tokenizer.texts_to_sequences([seed_text])[0]
    tokenized_seed = pad_sequences([tokenized_seed], maxlen=max_sequence_length-1, padding='pre')
    predicted_word_index = np.argmax(model.predict(tokenized_seed), axis=-1)
    predicted_word = tokenizer.index_word[predicted_word_index[0]]
    seed_text += " " + predicted_word

print(seed_text)
# Out:
# Enter the starting word: i hate
# Enter how many words to predict: 2
# ...
# 1/1 [==============================] - 0s 22ms/step
# i hate school love

# %% [markdown]
# *Decision trees in machine learning provide an effective method for making decisions because they are lay out the problem and all the possible
# *have nodes and leaves
# *condition having true and false branches'
# l*eaf:result-showing the dataset is true and false to condition
# state,literarcy,cleanliness,crime rate,good
# DECISION TREE recurrently split the data until it gets prue nodes
# #random forest
# collection of many decision trees
# keywords:bootstraping,aggregation
# y-taget
# x to x4-features
# random forest creating new datasets from the original daatsets
# theis is called bootstraping
# #conditions for boostrapping
# select rows that are different and cover all the rows
# select features that are different and cover all the features
# selecting same data and same features have no use
